# 2024-06-03  30195397
# ...

# %%
df['Close'].plot()
plt.show()

# %%
print(df[['Open','High']].head())
# Out:
#                  Open       High
# Date
# 2000-01-03  22.777777  23.822222
# 2000-01-04  22.388887  23.299999
# 2000-01-05  22.333332  24.788889
# 2000-01-06  26.000000  26.100000
# 2000-01-07  24.777777  24.777777

# %%
df['100ma'] = df['Adj Close'].rolling(window=100).mean()
#making our own column using pandas
df.dropna(inplace=True)
print(df.tail())
print(df.head())
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-06-03  277.950012  286.549988  273.200012  284.100006  281.910248
# 2024-06-04  285.000000  285.000000  223.000000  236.300003  234.478668
# 2024-06-05  247.000000  249.750000  230.449997  247.500000  245.592346
# 2024-06-06  254.000000  259.500000  249.250000  252.300003  250.355347
# 2024-06-07  253.500000  260.799988  251.800003  260.399994  258.392914
#
#               Volume       100ma
# Date
# 2024-06-03  30195397  260.710292
# 2024-06-04  72779900  261.018438
# 2024-06-05  37078551  261.375130
# 2024-06-06  30881233  261.761849
# 2024-06-07  22010688  262.214274
#                  Open       High        Low      Close  Adj Close  Volume  \
# Date
# 2000-05-19  12.861111  12.861111  12.222222  12.755555   4.138292  259524
# 2000-05-22  12.666666  12.888888  12.233333  12.761111   4.140095  210105
# 2000-05-23  12.566666  12.777777  12.361111  12.750000   4.136490  264762
# ...

# %%
#using subplots in matplotlib
#grid size, start poit, row span, cols span
ax1 = plt.subplot2grid((6,1),(0,0),rowspan = 5, colspan = 1)
ax2 = plt.subplot2grid((6,1),(5,0),rowspan = 5, colspan = 1,sharex = ax1)
ax1.plot(df.index, df['Adj Close'])   # line plot (x,y)
ax1.plot(df.index, df['100ma'])
ax2.bar(df.index,df['Volume'])
# Out:
# <BarContainer object of 5997 artists>

# %% [markdown]
# Pandas dataframe.resample() function is primarily used for time series data.
# A time series is a series of data points indexed (or listed or graphed) in time order. Most commonly, a time series is a sequence taken at successive equally spaced points in time. It is a Convenience method for frequency conversion and resampling of time series. Object must have a datetime-like index (DatetimeIndex, PeriodIndex, or TimedeltaIndex), or pass datetime-like values to the on or level keyword.

# %%
#resampling
#ohlc = open high low close

df_ohlc = df['Adj Close'].resample('1M').ohlc()
df_volume = df['Volume'].resample('1M').sum()
print(df_ohlc.head())
# Out:
#                 open      high       low     close
# Date
# 2000-05-31  4.138292  4.628543  4.136490  4.628543
# 2000-06-30  4.482548  5.569389  4.482548  5.084547
# 2000-07-31  5.039487  5.324265  4.852037  4.889891
# 2000-08-31  4.686218  4.861050  3.866131  4.222361
# 2000-09-30  4.222361  4.368025  3.931037  3.931037
# C:\Users\sp_kr\AppData\Local\Temp\ipykernel_10692\369550578.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_ohlc = df['Adj Close'].resample('1M').ohlc()
# C:\Users\sp_kr\AppData\Local\Temp\ipykernel_10692\369550578.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_volume = df['Volume'].resample('1M').sum()

# %%
# Combine OHLC and volume data into one DataFrame
df_resampled = df_ohlc.copy()
df_resampled['Volume'] = df_volume
df_resampled.rename(columns={'Volume': 'volume'}, inplace=True)

# Plot candlestick chart using mplfinance
mpf.plot(df_resampled, type='candle', volume=True, title='ONGC Stock Price (1Month OHLC)', style='yahoo')
